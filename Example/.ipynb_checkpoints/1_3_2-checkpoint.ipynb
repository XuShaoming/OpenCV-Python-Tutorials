# %% [raw]
# 1.3.2 Arithmetic Operations on Images

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import math

# %matplotlib inline

# %% [markdown]
# ### Image Blending

# %%
img1 = cv2.imread('../image/github_logo1.png')
img2 = cv2.imread('../image/github_logo2.png')
plt.imshow(img1)
dst = cv2.addWeighted(img1,0.7,img2,0.2,0)
plt.imshow(dst)

# %%
x = np.int8([250])
y = np.int8([10])
#should be [255] according the book
print(cv2.add(x,y)) 
print(x + y)
# Out:
# [[4]]
# [4]

# %%
##Bitwise Operations

# Load two images
img1 = cv2.imread('../image/messi5.jpg')
img2 = cv2.imread('../image/opencv_logo_white.png')
# I want to put logo on top-left corner, So I create a ROI
rows,cols,channels = img2.shape
roi = img1[0:rows, 0:cols]

# Now create a mask of logo and create its inverse mask also
img2gray = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)

#https://docs.opencv.org/3.4.0/d7/d4d/tutorial_py_thresholding.html
ret, mask = cv2.threshold(img2gray, 10, 255, cv2.THRESH_BINARY)
mask_inv = cv2.bitwise_not(mask)

# Now black-out the area of logo in ROI
img1_bg = cv2.bitwise_and(roi,roi,mask = mask_inv)

# Take only region of logo from logo image.
img2_fg = cv2.bitwise_and(img2,img2,mask = mask)

# Put logo in ROI and modify the main image
dst = cv2.add(img1_bg,img2_fg)
img1[0:rows, 0:cols ] = dst

#show images in matplotlib
img1_bg = cv2.cvtColor(img1_bg, cv2.COLOR_BGR2RGB)
img2_fg = cv2.cvtColor(img2_fg, cv2.COLOR_BGR2RGB)
dst = cv2.cvtColor(dst, cv2.COLOR_BGR2RGB)
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
plt.subplot(221), plt.imshow(img1_bg), plt.title('img1_bg')
plt.subplot(222), plt.imshow(img2_fg), plt.title('img2_fg')
plt.subplot(223), plt.imshow(dst), plt.title('dst')
plt.subplot(224), plt.imshow(img1), plt.title('img1')
plt.show()
